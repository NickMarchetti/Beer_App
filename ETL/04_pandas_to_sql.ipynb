# %%
import pandas as pd
from sqlalchemy import create_engine
import qgrid
import numpy as np

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
premise_file = "beers_brewery_locations_city_state.csv"
premise = pd.read_csv(premise_file)
del premise['Unnamed: 0']
premise.head()
# Out:
#                      Beer Total_Votes  Rating  \
# 0           Bitches' Bank         234    4.41
# 1     Marshmallow Handjee       1,682    4.73
# 2               Pear Bear         298    4.36
# 3    Barrel Aged Behemoth         474    4.36
# 4  French Vanilla Militia          35    4.51
#
#                               Brewery              Beer_Style     ABV  \
# 0  18th Street Brewery - Gary Taproom  Russian Imperial Stout  12.00%
# 1                3 Floyds Brewing Co.  Russian Imperial Stout  15.00%
# 2                3 Floyds Brewing Co.       American Wild Ale   7.50%
# 3                3 Floyds Brewing Co.     American Barleywine  12.50%
# 4                3 Floyds Brewing Co.  Russian Imperial Stout  15.00%
#
#         Region   Latitude  Longitude     City State
# 0  great-lakes  41.599057 -87.267179     Gary    IN
# 1  great-lakes  41.535525 -87.516811  Munster    IN
# 2  great-lakes  41.535525 -87.516811  Munster    IN
# 3  great-lakes  41.535525 -87.516811  Munster    IN
# 4  great-lakes  41.535525 -87.516811  Munster    IN

# %%
premise.dtypes
# Out:
# Beer            object
# Total_Votes     object
# Rating         float64
# Brewery         object
# Beer_Style      object
# ABV             object
# Region          object
# Latitude       float64
# Longitude      float64
# City            object
# State           object
# dtype: object

# %%
premise = premise.replace({'ABV': {'ld Ale': np.nan, 'eywine': np.nan, 'd Beer': np.nan, 'Stout': np.nan, 
                        'Saison': np.nan, 'Gueuze': np.nan, 'al IPA': np.nan}})

# %%
qgrid.show_grid(premise)
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
premise['Total_Votes'] = premise['Total_Votes'].str.replace(",","").astype(int)

# %%
premise['ABV'] = premise['ABV'].str.replace("%","").astype(float)

# %%
premise.dtypes
# Out:
# Beer            object
# Total_Votes      int64
# Rating         float64
# Brewery         object
# Beer_Style      object
# ABV            float64
# Region          object
# Latitude       float64
# Longitude      float64
# City            object
# State           object
# dtype: object

# %%
us_states = pd.read_csv('states.csv')

# %%
us_states.head()
# Out:
#         State Abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %% [markdown]
# ### Create database connection

# %%
#engine = create_engine("mysql://root@localhost/customer_db")
engine = create_engine("sqlite:///beer_brewery_db.sqlite")
conn = engine.connect()

# %%
#rds_connection_string = "<inser user name>:<insert password>@127.0.0.1/customer_db"
#engine = create_engine(f'mysql://{rds_connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['beer']

# %% [markdown]
# ### Load DataFrames into database

# %%
premise.head()
# Out:
#                      Beer Total_Votes  Rating  \
# 0           Bitches' Bank         234    4.41
# 1     Marshmallow Handjee       1,682    4.73
# 2               Pear Bear         298    4.36
# 3    Barrel Aged Behemoth         474    4.36
# 4  French Vanilla Militia          35    4.51
#
#                               Brewery              Beer_Style     ABV  \
# 0  18th Street Brewery - Gary Taproom  Russian Imperial Stout  12.00%
# 1                3 Floyds Brewing Co.  Russian Imperial Stout  15.00%
# 2                3 Floyds Brewing Co.       American Wild Ale   7.50%
# 3                3 Floyds Brewing Co.     American Barleywine  12.50%
# 4                3 Floyds Brewing Co.  Russian Imperial Stout  15.00%
#
#         Region   Latitude  Longitude     City State
# 0  great-lakes  41.599057 -87.267179     Gary    IN
# 1  great-lakes  41.535525 -87.516811  Munster    IN
# 2  great-lakes  41.535525 -87.516811  Munster    IN
# 3  great-lakes  41.535525 -87.516811  Munster    IN
# 4  great-lakes  41.535525 -87.516811  Munster    IN

# %%
#premise.to_sql(name='premis', con=engine, if_exists='append', index=False)

# %%
#pd.read_sql('belly_button_biodiversity.sqlite')

# %%
premise = premise.reset_index(drop=False)

#premise = premise.rename(index=str, columns={"index": "beer_key"})

premise.head()
# Out:
#    index                    Beer  Total_Votes  Rating  \
# 0      0           Bitches' Bank          234    4.41
# 1      1     Marshmallow Handjee         1682    4.73
# 2      2               Pear Bear          298    4.36
# 3      3    Barrel Aged Behemoth          474    4.36
# 4      4  French Vanilla Militia           35    4.51
#
#                               Brewery              Beer_Style   ABV  \
# 0  18th Street Brewery - Gary Taproom  Russian Imperial Stout  12.0
# 1                3 Floyds Brewing Co.  Russian Imperial Stout  15.0
# 2                3 Floyds Brewing Co.       American Wild Ale   7.5
# 3                3 Floyds Brewing Co.     American Barleywine  12.5
# 4                3 Floyds Brewing Co.  Russian Imperial Stout  15.0
#
#         Region   Latitude  Longitude     City State
# 0  great-lakes  41.599057 -87.267179     Gary    IN
# 1  great-lakes  41.535525 -87.516811  Munster    IN
# 2  great-lakes  41.535525 -87.516811  Munster    IN
# 3  great-lakes  41.535525 -87.516811  Munster    IN
# 4  great-lakes  41.535525 -87.516811  Munster    IN

# %%
premise.to_sql(name='beer', con=engine, if_exists='replace', index=False)

# %%
us_states.to_sql(name='us_states', con=engine, if_exists='replace', index=False)

# %%
pd.read_sql_query('select * from beer', con=engine)
# Out:
#      index                                               Beer  Total_Votes  \
# 0        0                                      Bitches' Bank          234
# 1        1                                Marshmallow Handjee         1682
# 2        2                                          Pear Bear          298
# 3        3                               Barrel Aged Behemoth          474
# 4        4                             French Vanilla Militia           35
# 5        5                                    Dreadnaught IPA         6128
# 6        6                                  Permanent Funeral         3013
# 7        7  BBADL (Bourbon Barrel Aged Dark Lord Imperial ...          932
# 8        8                3 Floyds / The Bruery - Rue D'Floyd          315
# 9        9                                       Chemtrailmix          117
# 10      10                                        Zombie Dust        10664
# 11      11     Lumberjack Morning Break - Bourbon Barrel-Aged           18
# 12      12                                         Madagascar          874
# 13      13                                         Volume # 1          215
# 14      14                                              Passé           38
# 15      15                                     London Balling          438
# 16      16                                          Bo & Luke          971
# 17      17                                                70K          357
# 18      18         Sunny Side Up (Little Amps! Double Coffee)          621
# 19      19                        Speedway Stout - Kopi Luwak          546
# 20      20                            Speedway Stout - Velvet          118
# 21      21                        Speedway Stout - Hammerhead          413
# 22      22               Speedway Stout - Bourbon Barrel-Aged         2253
# 23      23                                     Speedway Stout         7096
# 24      24                 Speedway Stout - Vietnamese Coffee         1952
# 25      25      Speedway Stout - Jamaica Blue Mountain Coffee          647
# 26      26  Speedway Stout - Vietnamese Coffee - Bourbon-B...          918
# 27      27                                       Coolship Red          705
# 28      28                                        Kiwi Herman          290
# 29      29                              Exponential Hoppiness         1328
# ..     ...                                                ...          ...
# 970    970                     Embrace The Funk - Deux Rouges          106
# 971    971                Embrace The Funk - Lovin On Peaches           11
# 972    972                  Embrace The Funk - Foeder Beer #1           20
# 973    973              Embrace The Funk - Cherry Deux Rouges           46
# 974    974              Embrace The Funk - Cassis Deux Rouges           13
# 975    975           Embrace The Funk - Deux Rouges Grand Cru           11
# 976    976                                                Sue          872
# 977    977                                          The Vigne           27
# 978    978                                 Nectarine Premiere          335
# 979    979                                   The Broken Truck          294
# 980    980                                          The Peach          255
# 981    981                                           The Lily          192
# 982    982                                           The Lucy          155
# 983    983  de Garde / SARA / Jester King - Elements Of Co...           57
# 984    984                                      Special Rouge          197
# 985    985                                          Framiscus           67
# 986    986                                         The Archer          170
# 987    987                                         Citra Hose          135
# 988    988                                        Nelson Hose          180
# 989    989                                        The Truffle           51
# 990    990                                            The Duo           51
# 991    991                                        The Orchard           24
# 992    992                                    The Boysenberry           88
# 993    993                                          Roseberry           73
# 994    994                                     Special Violet           55
# 995    995                                          The Kriek           44
# 996    996                                          Lee Kriek           95
# 997    997                                         The Bluest           29
# 998    998                                            Cran Bu          129
# 999    999                                               Hose          382
#
#      Rating                                 Brewery  \
# 0      4.41      18th Street Brewery - Gary Taproom
# 1      4.73                    3 Floyds Brewing Co.
# 2      4.36                    3 Floyds Brewing Co.
# 3      4.36                    3 Floyds Brewing Co.
# 4      4.51                    3 Floyds Brewing Co.
# 5      4.40                    3 Floyds Brewing Co.
# 6      4.50                    3 Floyds Brewing Co.
# 7      4.56                    3 Floyds Brewing Co.
# 8      4.43                    3 Floyds Brewing Co.
# 9      4.71                    3 Floyds Brewing Co.
# 10     4.58                    3 Floyds Brewing Co.
# 11     4.65                  3 Sons Brewing Company
# 12     4.44                     4 Hands Brewing Co.
# 13     4.38                     4 Hands Brewing Co.
# 14     4.50                     515 Brewing Company
# 15     4.17  Against The Grain Brewery & Smokehouse
# 16     4.25  Against The Grain Brewery & Smokehouse
# 17     4.32  Against The Grain Brewery & Smokehouse
# 18     4.37     Al's of Hampden / Pizza Boy Brewing
# 19     4.37                AleSmith Brewing Company
# 20     4.41                AleSmith Brewing Company
# 21     4.38                AleSmith Brewing Company
# 22     4.52                AleSmith Brewing Company
# 23     4.38                AleSmith Brewing Company
# 24     4.50                AleSmith Brewing Company
# 25     4.44                AleSmith Brewing Company
# 26     4.65                AleSmith Brewing Company
# 27     4.48                Allagash Brewing Company
# 28     4.52                     Alpine Beer Company
# 29     4.42                     Alpine Beer Company
# ..      ...                                     ...
# 970    4.26                   Yazoo Brewing Company
# 971    4.43                   Yazoo Brewing Company
# 972    4.28                   Yazoo Brewing Company
# 973    4.24                   Yazoo Brewing Company
# 974    4.38                   Yazoo Brewing Company
# 975    4.40                   Yazoo Brewing Company
# 976    4.12                   Yazoo Brewing Company
# 977    4.44                        de Garde Brewing
# 978    4.64                        de Garde Brewing
# 979    4.60                        de Garde Brewing
# 980    4.58                        de Garde Brewing
# 981    4.49                        de Garde Brewing
# 982    4.46                        de Garde Brewing
# 983    4.49                        de Garde Brewing
# 984    4.41                        de Garde Brewing
# 985    4.46                        de Garde Brewing
# 986    4.41                        de Garde Brewing
# 987    4.40                        de Garde Brewing
# 988    4.39                        de Garde Brewing
# 989    4.45                        de Garde Brewing
# 990    4.43                        de Garde Brewing
# 991    4.53                        de Garde Brewing
# 992    4.38                        de Garde Brewing
# 993    4.36                        de Garde Brewing
# 994    4.38                        de Garde Brewing
# 995    4.39                        de Garde Brewing
# 996    4.33                        de Garde Brewing
# 997    4.43                        de Garde Brewing
# 998    4.29                        de Garde Brewing
# 999    4.38                        de Garde Brewing
#
#                      Beer_Style   ABV          Region   Latitude   Longitude  \
# 0        Russian Imperial Stout  12.0     great-lakes  41.599057  -87.267179
# 1        Russian Imperial Stout  15.0     great-lakes  41.535525  -87.516811
# 2             American Wild Ale   7.5     great-lakes  41.535525  -87.516811
# 3           American Barleywine  12.5     great-lakes  41.535525  -87.516811
# 4        Russian Imperial Stout  15.0     great-lakes  41.535525  -87.516811
# 5         American Imperial IPA   9.5     great-lakes  41.535525  -87.516811
# 6         American Imperial IPA  10.5     great-lakes  41.535525  -87.516811
# 7        Russian Imperial Stout  15.0     great-lakes  41.535525  -87.516811
# 8      American Imperial Porter  14.4     great-lakes  41.535525  -87.516811
# 9        Russian Imperial Stout  15.0     great-lakes  41.535525  -87.516811
# 10      American Pale Ale (APA)   6.2     great-lakes  41.535525  -87.516811
# 11      American Imperial Stout  13.0  south-atlantic  26.057241  -80.143421
# 12   English Sweet / Milk Stout   9.3         midwest  38.614955  -90.197526
# 13      American Imperial Stout  10.5         midwest  38.614955  -90.197526
# 14      American Pale Ale (APA)   6.0         midwest  41.600003  -93.722757
# 15           British Barleywine  12.5           south  38.255490  -85.744022
# 16       Russian Imperial Stout  13.0           south  38.255490  -85.744022
# 17   English Sweet / Milk Stout  13.0           south  38.255490  -85.744022
# 18      American Imperial Stout   9.5    mid-atlantic  40.288473  -76.971409
# 19      American Imperial Stout  12.0         pacific  32.888186 -117.149848
# 20      American Imperial Stout  12.0         pacific  32.888186 -117.149848
# 21      American Imperial Stout  12.0         pacific  32.888186 -117.149848
# 22      American Imperial Stout  12.0         pacific  32.888186 -117.149848
# 23      American Imperial Stout  12.0         pacific  32.888186 -117.149848
# 24      American Imperial Stout  12.0         pacific  32.888186 -117.149848
# 25      American Imperial Stout  12.0         pacific  32.888186 -117.149848
# 26      American Imperial Stout  12.0         pacific  32.888186 -117.149848
# 27         Belgian Fruit Lambic   5.7     new-england  43.703148  -70.317693
# 28            American Wild Ale   7.0         pacific  32.715700 -117.161100
# 29        American Imperial IPA  11.0         pacific  32.715700 -117.161100
# ..                          ...   ...             ...        ...         ...
# 970            Flanders Red Ale   6.2           south  36.151022  -86.782177
# 971           American Wild Ale   6.0           south  36.151022  -86.782177
# 972           American Wild Ale   5.9           south  36.151022  -86.782177
# 973            Flanders Red Ale   6.2           south  36.151022  -86.782177
# 974            Flanders Red Ale   6.2           south  36.151022  -86.782177
# 975            Flanders Red Ale   6.2           south  36.151022  -86.782177
# 976    American Imperial Porter   9.0           south  36.151022  -86.782177
# 977           American Wild Ale   7.0       northwest  45.457287 -123.845383
# 978              Belgian Saison   7.1       northwest  45.457287 -123.845383
# 979           American Wild Ale   5.0       northwest  45.457287 -123.845383
# 980           American Wild Ale   7.3       northwest  45.457287 -123.845383
# 981           American Wild Ale   7.0       northwest  45.457287 -123.845383
# 982           American Wild Ale   8.0       northwest  45.457287 -123.845383
# 983           American Wild Ale   6.2       northwest  45.457287 -123.845383
# 984           American Wild Ale   6.4       northwest  45.457287 -123.845383
# 985           American Wild Ale   6.2       northwest  45.457287 -123.845383
# 986           American Wild Ale   7.0       northwest  45.457287 -123.845383
# 987                Leipzig Gose   4.0       northwest  45.457287 -123.845383
# 988                Leipzig Gose   5.0       northwest  45.457287 -123.845383
# 989           American Wild Ale   5.0       northwest  45.457287 -123.845383
# 990           American Wild Ale   6.0       northwest  45.457287 -123.845383
# 991           American Wild Ale   6.4       northwest  45.457287 -123.845383
# 992           American Wild Ale   7.0       northwest  45.457287 -123.845383
# 993           American Wild Ale   6.2       northwest  45.457287 -123.845383
# 994           American Wild Ale   6.4       northwest  45.457287 -123.845383
# 995           American Wild Ale   7.0       northwest  45.457287 -123.845383
# 996           American Wild Ale   8.4       northwest  45.457287 -123.845383
# 997           American Wild Ale   7.0       northwest  45.457287 -123.845383
# 998             Berliner Weisse   2.3       northwest  45.457287 -123.845383
# 999                Leipzig Gose   4.0       northwest  45.457287 -123.845383
#
#                    City State
# 0                  Gary    IN
# 1               Munster    IN
# 2               Munster    IN
# 3               Munster    IN
# 4               Munster    IN
# 5               Munster    IN
# 6               Munster    IN
# 7               Munster    IN
# 8               Munster    IN
# 9               Munster    IN
# 10              Munster    IN
# 11          Dania Beach    FL
# 12            St. Louis    MO
# 13            St. Louis    MO
# 14                Clive    IA
# 15           Louisville    KY
# 16           Louisville    KY
# 17           Louisville    KY
# 18           Mount View    PA
# 19            San Diego    CA
# 20            San Diego    CA
# 21            San Diego    CA
# 22            San Diego    CA
# 23            San Diego    CA
# 24            San Diego    CA
# 25            San Diego    CA
# 26            San Diego    CA
# 27             Portland    ME
# 28            San Diego    CA
# 29            San Diego    CA
# ..                  ...   ...
# 970  Nashville-Davidson    TN
# 971  Nashville-Davidson    TN
# 972  Nashville-Davidson    TN
# 973  Nashville-Davidson    TN
# 974  Nashville-Davidson    TN
# 975  Nashville-Davidson    TN
# 976  Nashville-Davidson    TN
# 977           Tillamook    OR
# 978           Tillamook    OR
# 979           Tillamook    OR
# 980           Tillamook    OR
# 981           Tillamook    OR
# 982           Tillamook    OR
# 983           Tillamook    OR
# 984           Tillamook    OR
# 985           Tillamook    OR
# 986           Tillamook    OR
# 987           Tillamook    OR
# 988           Tillamook    OR
# 989           Tillamook    OR
# 990           Tillamook    OR
# 991           Tillamook    OR
# 992           Tillamook    OR
# 993           Tillamook    OR
# 994           Tillamook    OR
# 995           Tillamook    OR
# 996           Tillamook    OR
# 997           Tillamook    OR
# 998           Tillamook    OR
# 999           Tillamook    OR
#
# [1000 rows x 12 columns]

# %%
pd.read_sql_query('select * from us_states', con=engine).head()
# Out:
#         State Abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
conn.close()
