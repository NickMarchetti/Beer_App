# %%
import pandas as pd

# %%
file = 'beers_brewery_locations_city_state.csv'
data = pd.read_csv(file)
del data['Unnamed: 0']
data.head()
# Out:
#                      Beer Total_Votes  Rating  \
# 0           Bitches' Bank         234    4.41
# 1     Marshmallow Handjee       1,682    4.73
# 2               Pear Bear         298    4.36
# 3    Barrel Aged Behemoth         474    4.36
# 4  French Vanilla Militia          35    4.51
#
#                               Brewery              Beer_Style     ABV  \
# 0  18th Street Brewery - Gary Taproom  Russian Imperial Stout  12.00%
# 1                3 Floyds Brewing Co.  Russian Imperial Stout  15.00%
# 2                3 Floyds Brewing Co.       American Wild Ale   7.50%
# 3                3 Floyds Brewing Co.     American Barleywine  12.50%
# 4                3 Floyds Brewing Co.  Russian Imperial Stout  15.00%
#
#         Region   Latitude  Longitude     City State
# 0  great-lakes  41.599057 -87.267179     Gary    IN
# 1  great-lakes  41.535525 -87.516811  Munster    IN
# 2  great-lakes  41.535525 -87.516811  Munster    IN
# 3  great-lakes  41.535525 -87.516811  Munster    IN
# ...

# %%
new_data = data.copy()

del new_data['Latitude']
del new_data['Longitude']
del new_data['Region']
del new_data['ABV']
del new_data['Rating']
del new_data['Total_Votes']

new_data.head()
# Out:
#                      Beer                             Brewery  \
# 0           Bitches' Bank  18th Street Brewery - Gary Taproom
# 1     Marshmallow Handjee                3 Floyds Brewing Co.
# 2               Pear Bear                3 Floyds Brewing Co.
# 3    Barrel Aged Behemoth                3 Floyds Brewing Co.
# 4  French Vanilla Militia                3 Floyds Brewing Co.
#
#                Beer_Style     City State
# 0  Russian Imperial Stout     Gary    IN
# 1  Russian Imperial Stout  Munster    IN
# 2       American Wild Ale  Munster    IN
# 3     American Barleywine  Munster    IN
# 4  Russian Imperial Stout  Munster    IN

# %%
new_data.groupby(['Beer_Style', 'State', 'City', 'Brewery', 'Beer']).count()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
new_data.describe()
# Out:
#               Beer                 Brewery               Beer_Style  \
# count         1000                    1000                     1000
# unique         996                     233                       50
# top     Mosaic IPA  Other Half Brewing Co.  American Imperial Stout
# freq             2                      39                      222
#
#                  City State
# count            1000  1000
# unique            171    41
# top     New York City    CA
# freq               55   100
